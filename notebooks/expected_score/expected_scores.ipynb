# %% [markdown]
# Expected Score Model

# %% [markdown]
# Combine Expected Goals and Behind models for set shots and open play shots together.

# %%
import sys
sys.path.append("/Users/ciaran/Documents/Projects/AFL/git-repositories/expected-score-model/")

# %%
import pandas as pd
import numpy as np
import joblib
import warnings
warnings.filterwarnings('ignore')

from expected_score_model.config import *
from expected_score_model.domain.preprocessing.preprocessing import expected_score_response_processing
from expected_score_model.domain.contracts.modelling_data_contract import ModellingDataContract
from expected_score_model.domain.modelling.supermodel import SuperXGBClassifier
from expected_score_model.domain.modelling.model_evaluation import XGBClassifierEvaluator

pd.options.display.max_rows = 999
pd.options.display.max_columns = 999

# %load_ext autoreload
# %autoreload 2
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# Expected Score Version

# %%
expected_score_version = 4

# %% [markdown]
# Models

# %%
expected_goal_set_model = joblib.load(exp_goal_set_model_file_path)
expected_behind_set_model = joblib.load(exp_behind_set_model_file_path)
expected_miss_set_model = joblib.load(exp_miss_set_model_file_path)

expected_goal_open_model = joblib.load(exp_goal_open_model_file_path)
expected_behind_open_model = joblib.load(exp_behind_open_model_file_path)
expected_miss_open_model = joblib.load(exp_miss_open_model_file_path)

# %% [markdown]
# Data

# %%
chain_data = pd.read_csv(chain_file_path, low_memory=False)
chain_data.head()
# Out:
#    Chain_Number Initial_State Final_State  Order  Quarter  \
# 0             1  centreBounce        goal    1.0        1
# 1             1  centreBounce        goal    2.0        1
# 2             1  centreBounce        goal    3.0        1
# 3             1  centreBounce        goal    4.0        1
# 4             1  centreBounce        goal    5.0        1
#
#    Quarter_Duration_Chain_Start  Quarter_Duration      Team_Chain  \
# 0                            13              13.0  Brisbane Lions
# 1                            13              24.0  Brisbane Lions
# 2                            13              24.0  Brisbane Lions
# 3                            13              28.0  Brisbane Lions
# 4                            13              29.0  Brisbane Lions
#
#              Team          Player AFL_API_Player_ID     Description     x  \
# 0             NaN             NaN               NaN   Centre Bounce   0.0
# 1  Brisbane Lions     Dayne Zorko       Dayne_Zorko   Hard Ball Get   8.0
# 2  Brisbane Lions     Dayne Zorko       Dayne_Zorko        Handball   9.0
# 3          Sydney  Oliver Florent    Oliver_Florent  Loose Ball Get  11.0
# 4          Sydney  Oliver Florent    Oliver_Florent        Handball  12.0
#
#      y     Disposal Shot_At_Goal Behind_Detail  Venue_Width  Venue_Length  \
# 0  0.0          NaN          NaN           NaN          138           156
# 1 -5.0          NaN          NaN           NaN          138           156
# 2 -6.0  ineffective          NaN           NaN          138           156
# 3 -7.0          NaN          NaN           NaN          138           156
# 4 -5.0    effective          NaN           NaN          138           156
#
#         Home_Team Away_Team Home_Team_Direction_Q1  \
# 0  Brisbane Lions    Sydney                  right
# 1  Brisbane Lions    Sydney                  right
# 2  Brisbane Lions    Sydney                  right
# 3  Brisbane Lions    Sydney                  right
# 4  Brisbane Lions    Sydney                  right
#
#                       Match_ID Round_ID    Year  Season
# 0  202101_BrisbaneLions_Sydney   202101  2021.0     NaN
# 1  202101_BrisbaneLions_Sydney   202101  2021.0     NaN
# 2  202101_BrisbaneLions_Sydney   202101  2021.0     NaN
# 3  202101_BrisbaneLions_Sydney   202101  2021.0     NaN
# 4  202101_BrisbaneLions_Sydney   202101  2021.0     NaN

# %% [markdown]
# Processing

# %%
chain_data = expected_score_response_processing(chain_data)
chain_data['Event_Type1'] = chain_data['Description'].shift(1)
df_shots = chain_data[chain_data['Shot_At_Goal'] == True]
df_shots['Set_Shot'] = df_shots['Event_Type1'].apply(lambda x: ("Mark" in x) or ("Free" in x))
df_set_shots = df_shots[df_shots['Set_Shot']]
df_open_shots = df_shots[~df_shots['Set_Shot']]

# %%
goal_set_preproc = joblib.load(exp_goal_set_preprocessor_file_path)
behind_set_preproc = joblib.load(exp_behind_set_preprocessor_file_path)
miss_set_preproc = joblib.load(exp_miss_set_preprocessor_file_path)

goal_open_preproc = joblib.load(exp_goal_open_preprocessor_file_path)
behind_open_preproc = joblib.load(exp_behind_open_preprocessor_file_path)
miss_open_preproc = joblib.load(exp_miss_open_preprocessor_file_path)

# %%
set_goal_features = goal_set_preproc.transform(chain_data)
set_behind_features = behind_set_preproc.transform(chain_data)
set_miss_features = miss_set_preproc.transform(chain_data)

open_goal_features = goal_open_preproc.transform(chain_data)
open_behind_features = behind_open_preproc.transform(chain_data)
open_miss_features = miss_open_preproc.transform(chain_data)

# %% [markdown]
# Predictions

# %%
df_set_shots['xGoals'] = expected_goal_set_model.predict_proba(set_goal_features, calibrate=True)
df_set_shots['xBehinds'] = expected_behind_set_model.predict_proba(set_behind_features, calibrate=True)
df_set_shots['xMiss'] = expected_miss_set_model.predict_proba(set_miss_features, calibrate=True)

df_open_shots['xGoals'] = expected_goal_open_model.predict_proba(open_goal_features, calibrate=True)
df_open_shots['xBehinds'] = expected_behind_open_model.predict_proba(open_behind_features, calibrate=True)
df_open_shots['xMiss'] = expected_miss_open_model.predict_proba(open_miss_features, calibrate=True)

# %% [markdown]
# Combine

# %%
df_shots = pd.concat([df_set_shots, df_open_shots], axis=0)
df_shots = df_shots.sort_values(by = ['Match_ID', "Chain_Number", "Order"])
df_shots.head()
# Out:
#      Chain_Number Initial_State Final_State  Order  Quarter  \
# 10              1  centreBounce        goal   11.0        1
# 60              6      possGain        goal   61.0        1
# 109            10      possGain        goal  110.0        1
# 182            17        kickIn      behind  183.0        1
# 221            21      possGain        goal  222.0        1
#
#      Quarter_Duration_Chain_Start  Quarter_Duration      Team_Chain  \
# 10                             13              39.0  Brisbane Lions
# 60                            149             168.0  Brisbane Lions
# 109                           285             306.0  Brisbane Lions
# 182                           520             582.0          Sydney
# 221                           653             666.0          Sydney
#
#                Team          Player AFL_API_Player_ID Description     x     y  \
# 10   Brisbane Lions      Zac Bailey        Zac_Bailey        Kick  26.0 -21.0
# 60   Brisbane Lions      Zac Bailey        Zac_Bailey        Kick  35.0  19.0
# 109  Brisbane Lions     Joe Daniher       Joe_Daniher        Kick  50.0  24.0
# 182          Sydney    Isaac Heeney      Isaac_Heeney        Kick  46.0 -41.0
# 221          Sydney  Logan McDonald    Logan_McDonald        Kick  34.0  15.0
#
#         Disposal Shot_At_Goal Behind_Detail  Venue_Width  Venue_Length  \
# 10     effective         True           NaN          138           156
# 60     effective         True           NaN          138           156
# 109    effective         True           NaN          138           156
# 182  ineffective         True           NaN          138           156
# 221    effective         True           NaN          138           156
#
#           Home_Team Away_Team Home_Team_Direction_Q1  \
# 10   Brisbane Lions    Sydney                  right
# 60   Brisbane Lions    Sydney                  right
# 109  Brisbane Lions    Sydney                  right
# 182  Brisbane Lions    Sydney                  right
# 221  Brisbane Lions    Sydney                  right
#
#                         Match_ID Round_ID    Year  Season  Goal  Behind  Miss  \
# 10   202101_BrisbaneLions_Sydney   202101  2021.0     NaN     1       0     0
# 60   202101_BrisbaneLions_Sydney   202101  2021.0     NaN     1       0     0
# 109  202101_BrisbaneLions_Sydney   202101  2021.0     NaN     1       0     0
# 182  202101_BrisbaneLions_Sydney   202101  2021.0     NaN     0       1     0
# 221  202101_BrisbaneLions_Sydney   202101  2021.0     NaN     1       0     0
#
#      Score        Event_Type1  Set_Shot    xGoals  xBehinds     xMiss
# 10       6  Handball Received     False  0.289081  0.477460  0.173369
# 60       6  Handball Received     False  0.313268  0.396646  0.258089
# 109      6             Gather     False  0.495607  0.430808  0.281173
# 182      1       Mark On Lead      True  0.325491  0.413704  0.393362
# 221      6  Handball Received     False  0.329359  0.416202  0.186615

# %% [markdown]
# Checks

# %%
(df_shots['xGoals'] + df_shots['xBehinds'] + df_shots['xMiss']).max()
# Out:
# 1.3725281398818756

# %% [markdown]
# Normalize

# %%
df_shots['xGoals_normalised'] = df_shots['xGoals'] / (df_shots['xGoals'] + df_shots['xBehinds'] + df_shots['xMiss'])
df_shots['xBehinds_normalised'] = df_shots['xBehinds'] / (df_shots['xGoals'] + df_shots['xBehinds'] + df_shots['xMiss'])
df_shots['xMiss_normalised'] = df_shots['xMiss'] / (df_shots['xGoals'] + df_shots['xBehinds'] + df_shots['xMiss'])

# %% [markdown]
# Create Expected Score

# %%
df_shots['xScore'] = df_shots['xGoals_normalised']*6 + df_shots['xBehinds_normalised']

# %% [markdown]
# Evaluate

# %%
df_shots[['Score', 'xScore']].sum()
# Out:
# Score     98324.000000
# xScore    98987.103621
# dtype: float64

# %%
df_shots[['Score', 'xScore']].describe()
# Out:
#               Score        xScore
# count  29906.000000  29906.000000
# mean       3.287768      3.309941
# std        2.682481      0.970739
# min        0.000000      1.489613
# 25%        1.000000      2.553543
# 50%        1.000000      3.106996
# 75%        6.000000      3.918454
# max        6.000000      5.740831

# %%
df_shots[df_shots['Set_Shot']][['Score', 'xScore']].sum()
# Out:
# Score     58570.000000
# xScore    58707.781706
# dtype: float64

# %%
df_shots[df_shots['Set_Shot']][['Score', 'xScore']].describe()
# Out:
#               Score        xScore
# count  16310.000000  16310.000000
# mean       3.591048      3.599496
# std        2.646786      1.014446
# min        0.000000      1.716920
# 25%        1.000000      2.843671
# 50%        6.000000      3.421003
# 75%        6.000000      4.222578
# max        6.000000      5.740831

# %%
df_shots[~df_shots['Set_Shot']][['Score', 'xScore']].sum()
# Out:
# Score     39754.000000
# xScore    40279.321915
# dtype: float64

# %%
df_shots[~df_shots['Set_Shot']][['Score', 'xScore']].describe()
# Out:
#               Score        xScore
# count  13596.000000  13596.000000
# mean       2.923948      2.962586
# std        2.679871      0.785535
# min        0.000000      1.489613
# 25%        1.000000      2.384906
# 50%        1.000000      2.786534
# 75%        6.000000      3.349551
# max        6.000000      5.123928

# %% [markdown]
# Merge xScore to Chain

# %%
chain_data.shape
# Out:
# (1237133, 65)

# %%
chain_data = chain_data.merge(df_shots[['Match_ID', "Chain_Number", "Order", 'xGoals', 'xBehinds', 'xMiss', 'xGoals_normalised', 'xBehinds_normalised', 'xMiss_normalised', 'xScore']], how = "left", on = ['Match_ID', "Chain_Number", "Order"])
chain_data.shape
# Out:
# (1237133, 72)

# %%
chain_data.head()
# Out:
#    Chain_Number Initial_State Final_State  Order  Quarter  \
# 0             1  centreBounce        goal    1.0        1
# 1             1  centreBounce        goal    2.0        1
# 2             1  centreBounce        goal    3.0        1
# 3             1  centreBounce        goal    4.0        1
# 4             1  centreBounce        goal    5.0        1
#
#    Quarter_Duration_Chain_Start  Quarter_Duration      Team_Chain  \
# 0                            13              13.0  Brisbane Lions
# 1                            13              24.0  Brisbane Lions
# 2                            13              24.0  Brisbane Lions
# 3                            13              28.0  Brisbane Lions
# 4                            13              29.0  Brisbane Lions
#
#              Team          Player AFL_API_Player_ID     Description     x  \
# 0             NaN             NaN               NaN   Centre Bounce   0.0
# 1  Brisbane Lions     Dayne Zorko       Dayne_Zorko   Hard Ball Get   8.0
# 2  Brisbane Lions     Dayne Zorko       Dayne_Zorko        Handball   9.0
# 3          Sydney  Oliver Florent    Oliver_Florent  Loose Ball Get  11.0
# 4          Sydney  Oliver Florent    Oliver_Florent        Handball  12.0
#
#      y     Disposal Shot_At_Goal Behind_Detail  Venue_Width  Venue_Length  \
# 0  0.0          NaN          NaN           NaN          138           156
# 1 -5.0          NaN          NaN           NaN          138           156
# 2 -6.0  ineffective          NaN           NaN          138           156
# 3 -7.0          NaN          NaN           NaN          138           156
# 4 -5.0    effective          NaN           NaN          138           156
#
#         Home_Team Away_Team Home_Team_Direction_Q1  \
# 0  Brisbane Lions    Sydney                  right
# 1  Brisbane Lions    Sydney                  right
# 2  Brisbane Lions    Sydney                  right
# 3  Brisbane Lions    Sydney                  right
# 4  Brisbane Lions    Sydney                  right
#
#                       Match_ID Round_ID    Year  Season  Goal  Behind  Miss  \
# 0  202101_BrisbaneLions_Sydney   202101  2021.0     NaN     0       0     0
# 1  202101_BrisbaneLions_Sydney   202101  2021.0     NaN     0       0     0
# 2  202101_BrisbaneLions_Sydney   202101  2021.0     NaN     0       0     0
# 3  202101_BrisbaneLions_Sydney   202101  2021.0     NaN     0       0     0
# 4  202101_BrisbaneLions_Sydney   202101  2021.0     NaN     0       0     0
#
#    Score     Event_Type1  ballUp  centreBounce  kickIn  possGain  throwIn  \
# 0      0            None       0             1       0         0        0
# 1      0   Centre Bounce       0             1       0         0        0
# 2      0   Hard Ball Get       0             1       0         0        0
# 3      0        Handball       0             1       0         0        0
# 4      0  Loose Ball Get       0             1       0         0        0
#
#       Event_Type0    Event_Type2    Event_Type3    x0    x1   x2   x3   y0  \
# 0   Centre Bounce           None           None   0.0   NaN  NaN  NaN  0.0
# 1   Hard Ball Get           None           None   8.0   0.0  NaN  NaN -5.0
# 2        Handball  Centre Bounce           None   9.0   8.0  0.0  NaN -6.0
# 3  Loose Ball Get  Hard Ball Get  Centre Bounce  11.0   9.0  8.0  0.0 -7.0
# 4        Handball       Handball  Hard Ball Get  12.0  11.0  9.0  8.0 -5.0
#
#     y1   y2   y3  Quarter_Duration0  Quarter_Duration1  Quarter_Duration2  \
# 0  NaN  NaN  NaN               13.0                NaN                NaN
# 1  0.0  NaN  NaN               24.0               13.0                NaN
# 2 -5.0  0.0  NaN               24.0               24.0               13.0
# 3 -6.0 -5.0  0.0               28.0               24.0               24.0
# 4 -7.0 -6.0 -5.0               29.0               28.0               24.0
#
#    Quarter_Duration3  Time_Since_Last_Action  Distance_Since_Last_Action  \
# 0                NaN                     NaN                         NaN
# 1                NaN                    11.0                    9.433981
# 2                NaN                     0.0                    1.414214
# 3               13.0                     4.0                    2.236068
# 4               24.0                     1.0                    2.236068
#
#    Chain_Duration  Distance_to_Right_Goal_x  Distance_to_Middle_y  \
# 0             0.0                      78.0                   0.0
# 1            11.0                      70.0                   5.0
# 2            11.0                      69.0                   6.0
# 3            15.0                      67.0                   7.0
# 4            16.0                      66.0                   5.0
#
#    Distance_to_Middle_Goal  Angle_to_Middle_Goal  \
# 0                78.000000              0.000000
# 1                70.178344              0.071307
# 2                69.260378              0.086738
# 3                67.364679              0.104100
# 4                66.189123              0.075613
#
#    Angle_to_Middle_Goal_degrees  Visible_Goal_Angle  \
# 0                      0.000000            0.082190
# 1                      4.085617            0.091154
# 2                      4.969741            0.092254
# 3                      5.964487            0.094705
# 4                      4.332314            0.096642
#
#    Visible_Goal_Angle_degrees  Visible_Behind_Angle  \
# 0                    4.709118              0.249940
# 1                    5.222739              0.278097
# 2                    5.285792              0.281582
# 3                    5.426178              0.289349
# 4                    5.537192              0.295465
#
#    Visible_Behind_Angle_degrees  Squared_Distance_to_Middle_Goal  \
# 0                     14.320502                           6084.0
# 1                     15.933804                           4900.0
# 2                     16.133481                           4761.0
# 3                     16.578485                           4489.0
# 4                     16.928869                           4356.0
#
#    Log_Distance_to_Middle_Goal  xGoals  xBehinds  xMiss  xGoals_normalised  \
# 0                     4.356709     NaN       NaN    NaN                NaN
# 1                     4.248495     NaN       NaN    NaN                NaN
# 2                     4.234107     NaN       NaN    NaN                NaN
# 3                     4.204693     NaN       NaN    NaN                NaN
# 4                     4.189655     NaN       NaN    NaN                NaN
#
#    xBehinds_normalised  xMiss_normalised  xScore
# 0                  NaN               NaN     NaN
# 1                  NaN               NaN     NaN
# 2                  NaN               NaN     NaN
# 3                  NaN               NaN     NaN
# 4                  NaN               NaN     NaN

# %% [markdown]
# Export Shots with xScore

# %%
df_shots.tail()

# %%
df_shots.to_csv("/Users/ciaran/Documents/Projects/AFL/git-repositories/expected-score-model/data/shot_chains_expected_score_v"+str(expected_score_version)+"_202319.csv", index=False)

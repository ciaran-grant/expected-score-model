# %% [markdown]
# Team Rolling Averages - Expected Score
#
# - Expected Score For v Against

# %%
import sys
sys.path.append("..")

# %%
import pandas as pd
import matplotlib.patheffects as pe
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from highlight_text import fig_text, ax_text
import matplotlib.gridspec as gridspec
import matplotlib.font_manager as fm

import os
import warnings
warnings.filterwarnings('ignore')
pd.options.display.max_rows = 100
pd.options.display.max_columns = 999

from viz.afl_colours import team_colours
from rolling_expected_score import *

# %%
font_path = "/Users/ciaran/Documents/Projects/AFL/git-repositories/expected-score-model/notebooks/visualisations/viz/fonts"
for x in os.listdir(font_path):
    if x != ".DS_Store":
        for y in os.listdir(f"{font_path}/{x}"):
            if y.split(".")[-1] == "ttf":
                fm.fontManager.addfont(f"{font_path}/{x}/{y}")
                try:
                    fm.FontProperties(weight=y.split("-")[-1].split(".")[0].lower(), fname=y.split("-")[0])
                except Exception:
                    continue

# %%
plt.style.use("/Users/ciaran/Documents/Projects/AFL/git-repositories/expected-score-model/notebooks/visualisations/viz/mplstyle/dark_theme.mplstyle")

# %% [markdown]
# Data

# %%
df_shots = pd.read_csv("/Users/ciaran/Documents/Projects/AFL/git-repositories/expected-score-model/data/shot_chains_xScore.csv", low_memory=False)
df_shots.head()
# Out:
#    Chain_Number Initial_State Final_State  Order  Quarter  \
# 0             1  centreBounce        goal   11.0        1
# 1             6      possGain        goal   61.0        1
# 2            10      possGain        goal  110.0        1
# 3            17        kickIn      behind  183.0        1
# 4            21      possGain        goal  222.0        1
#
#    Quarter_Duration_Chain_Start  Quarter_Duration      Team_Chain  \
# 0                            13              39.0  Brisbane Lions
# 1                           149             168.0  Brisbane Lions
# 2                           285             306.0  Brisbane Lions
# 3                           520             582.0          Sydney
# 4                           653             666.0          Sydney
#
#              Team          Player AFL_API_Player_ID Description     x     y  \
# 0  Brisbane Lions      Zac Bailey        Zac_Bailey        Kick  26.0 -21.0
# ...

# %% [markdown]
# Single Team

# %%
team = "Richmond"

# %%
fig = plt.figure()
ax = plt.subplot(111)
get_expected_rolling_plot(ax, team, data=df_shots, window=10, color_for=team_colours[team]['positive'], color_against = team_colours[team]['negative'])
# Out:
# <Axes: >

# %% [markdown]
# Plot all teams

# %%
team_list = list(team_colours.keys())
team_list
# Out:
# ['Adelaide',
#  'Brisbane Lions',
#  'Carlton',
#  'Collingwood',
#  'Essendon',
#  'Fremantle',
#  'Geelong',
#  'Gold Coast',
#  'Greater Western Sydney',
#  'Hawthorn',
#  'Melbourne',
#  'North Melbourne',
#  'Port Adelaide',
#  'Richmond',
#  'St Kilda',
#  'Sydney',
#  'West Coast',
#  'Western Bulldogs']

# %%
fig = plt.figure(figsize=(18, 24), dpi=300)

nrows=6
ncols=3
gspec = gridspec.GridSpec(
    ncols=ncols, nrows=nrows, figure=fig,
    hspace=0.3
)
plot_counter = 0
for row in range(nrows):
    for col in range(ncols):
        team = team_list[plot_counter]
        colour_for = team_colours[team]['positive']
        colour_against = team_colours[team]['negative']
        ax = plt.subplot(gspec[row, col])
        get_expected_rolling_plot(ax, team, data=df_shots, window=10, color_for=colour_for, color_against=colour_against)
        plot_counter+=1

fig_text(
    x=0.13, y=0.92,
    s = "Expected Score For & Against - 10-game rolling average.",
    size = 22,
    font = "Karla"
)
fig_text(
    x=0.13, y=0.905,
    s = "xS for & xS against values are @ end of 2022.",
    size = 14,
    font = "Karla"
)

plt.savefig(
	"figures/20230718_afl_rolling_xS.png",
	dpi = 600,
	facecolor = "#121212",
	bbox_inches="tight",
    edgecolor="none",
	transparent = False
)

plt.savefig(
	"figures/20230718_afl_rolling_xS_tr.png",
	dpi = 600,
	facecolor = "none",
	bbox_inches="tight",
    edgecolor="none",
	transparent = True
)
